# %% [markdown]
# link: https://www.hackerrank.com/challenges/reverse-shuffle-merge/problem

# %%
from IPython.display import Image
Image(filename='C:/Users/Sudheera/Desktop/uselss/capture.png',width=800, height=400)

# %%
from IPython.display import Image
Image(filename='C:/Users/Sudheera/Desktop/uselss/capture.png',width=800, height=400)

# %%
from IPython.display import Image
Image(filename='C:/Users/Sudheera/Desktop/uselss/capture.png',width=800, height=400)

# %% [markdown]
# # method 1
# simple method
#
# count keeps track of number of appearances of each characters
#
# need is exactly half of each value of count because the solution has half the length of given string and half the characters each
#
# when we reverse a string, we for sure know that

# %%
# %%timeit
from collections import defaultdict

def solve(S):
    """
    >>> solve('eggegg')
    'egg'
    >>> solve('abccba')
    'abc'
    >>> solve('ccbbaa')
    'abc'
    >>> solve('aabbcc')
    'cba'
    >>> solve('gaezgzageg')
    'agzeg'
    """
    # Reverse S
    S = S[::-1]
#     print(S)

    # Count each character in S.
    count = defaultdict(int)
    for c in S:
        count[c] += 1
#     print(count)
    need = {}
    for c in count:
        need[c] = count[c] / 2
#     print('need',need)
    solution = []
    i = 0
    while len(solution) < len(S) / 2:
        min_char_at = -1
        while True:
            c = S[i]
            if need[c] > 0 and (min_char_at < 0 or c < S[min_char_at]):
                min_char_at = i
            count[c] -= 1
            if count[c] < need[c]:
#                 print('min_char_at',min_char_at)
                break
            i += 1
#         print('min_char_at',min_char_at)
        # Restore all chars right of the minimum character.
        for j in range(min_char_at+1, i+1):
            count[S[j]] += 1

        need[S[min_char_at]] -= 1
        solution.append(S[min_char_at])
#         print('Solution',solution)

        i = min_char_at + 1
    return ''.join(solution)

if __name__ == '__main__':
    print(solve(input(from IPython.display import Image
Image(filename='C:/Users/Sudheera/Desktop/uselss/capture.png',width=800, height=400))))
#     print(solve('...'))
#     import doctest
#     doctest.testmod()
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# 355 ms ± 42.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#aswer i ot for that big test case
s1 = '...'

# %% [markdown]
# # a big test case which is porducing runtime error
# link https://hr-testcases-us-east-1.s3.amazonaws.com/674/input08.txt?AWSAccessKeyId=AKIAJ4WZFDFQTZRGO3QA&Expires=1562246946&Signature=4nZDusaFR7zT6J44pe5hh6%2BpUV4%3D&response-content-type=text%2Fplain
#
#
# ...

# %%
#expected output
s2 = '...'

# %%
s1==s2
# Out:
# True

# %%
# %%timeit
import math
import os
import random
import re
import sys
from collections import Counter

# Complete the reverseShuffleMerge function below.
def reverseShuffleMerge(s):
    word = []
    freqs = Counter(s)
    reqs = { k: v/2 for k, v in freqs.items()}  # required letters
    avail_skips = { k: v/2 for k, v in freqs.items()}  # available skips
    skipped = []  # short history of letters that have been skipped
    
    for c in reversed(s):
        # No longer need this character so skip
        if reqs[c] == 0:
            continue
        
        # Skip current character if possible
        if avail_skips[c] > 0:
            avail_skips[c] -= 1
            skipped.append(c)  # track history of skipped chars to add back in to the word later

        ### Can no longer skip current character
        ## If history of skipped chars is empty then just add the current character
        elif len(skipped) == 0:
            word.append(c)
            
        ## Else add back all skipped characters from cheapest to current letter
        else:
            i = 0
            skipped.append(c)
            avail_skips[c] -= 1
            min_c = chr(ord('a') - 1)

            while i < len(skipped):
                # find the cheapest skipped character
                i = index_of(skipped, find_min_bounded(skipped, i, min_c), i)
                sc = skipped[i]
                
                # if this skipped character (sc) is already fulfilled go to next cheapest
                if reqs[sc] == 0:
                    min_c = sc
                    continue

                # process the current sc
                word.append(sc)
                reqs[sc] -= 1
                avail_skips[sc] += 1
                i += 1

                # if the sc is at the current character 
                # we've processed one instance of it making it skippable again ... so break
                if sc == c:
                    break                

            # clear out all skipped characters that we've already processed
            skipped = skipped[i:]

    return ''.join(word)


def find_min_bounded(arr, start, min_c):
    m = 'z'
    for i in range(start, len(arr)):
        if arr[i] < m and arr[i] > min_c:
            m = arr[i]
    return m


def index_of(arr, v, start):
    for i in range(start, len(arr)):
        if arr[i] == v:
            return i


if __name__ == '__main__':
#     fptr = open(os.environ['OUTPUT_PATH'], 'w')

#     s = input()
    s = '...'

    result = reverseShuffleMerge(s)
    print(result)
#     fptr.write(result + '\n')

#     fptr.close()
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# 51.5 ms ± 3.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# first method is worse than the second, 1st took only 355 msec where as second took around 55 msec
